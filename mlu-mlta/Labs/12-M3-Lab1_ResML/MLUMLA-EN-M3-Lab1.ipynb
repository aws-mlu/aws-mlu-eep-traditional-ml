# %% [markdown]
# <p style="padding: 10px; border: 1px solid black;">
# <img src="../common/images/mlu-logo.png" alt="drawing" width="400"/> <br/>
# <div style="background-image: linear-gradient(145deg, rgba(35, 47, 62, 1) 0%, rgba(51, 0, 102, 1) 40%, rgba(223, 42, 93, 1) 60%, rgba(124, 90, 237, 1) 85%, rgba(124, 232, 244, 1) 100%); padding: 20px; border-radius: 10px; text-align: center; margin-bottom: 30px;">
#     <h1 style="color: white; margin: 0;">MLU: ML through Application</h1>
#     <h2 style="color: white; margin-top: 15px;">Introduction to Fairness and Bias Mitigation in ML</h2>
# </div>

# %% [markdown]
# <!-- Compact Lab Introduction with Activity/Challenge Explanation -->
# <div style="background-color: #F8F9F9; padding: 15px; border-radius: 5px; margin: 20px 0;">
#     <h4 style="color: #2E4053; margin-top: 0;">About This Lab</h4>
#     <p>Throughout this lab, you will encounter two types of interactive elements:</p>
#     <table style="width: 100%; border-collapse: collapse; margin: 15px 0;">
#         <tr>
#             <td style="text-align: center; padding: 10px; width: 50%;">
#                 <img src="../common/images/mlu-activity.png" alt="Activity" width="125"/>
#             </td>
#             <td style="text-align: center; padding: 10px; width: 50%;">
#                 <img src="../common/images/mlu-challenge.png" alt="Challenge" width="125"/>
#             </td>
#         </tr>
#         <tr>
#             <td style="text-align: center; padding: 10px; background-color: #EBF5FB;">
#                 <p>No coding is needed for an activity. You try to understand a concept, <br/>answer questions, or run a code cell.</p>
#             </td>
#             <td style="text-align: center; padding: 10px; background-color: #FEF9E7;">
#                 <p>Challenges are where you test your understanding by implementing something new or taking a short quiz.</p>
#             </td>
#         </tr>
#     </table>
#     <p>Please work through this notebook from top to bottom to avoid errors due to missing code or context.</p>
# </div>

# %% [markdown]
# <!-- Table of Contents with All Section Levels -->
# <div style="background-color: #f2f0fc; padding: 15px; border-radius: 5px; margin-bottom: 30px;">
#     <h2 style="color: #2f1381; border-bottom: 1px solid #2f1381; padding-bottom: 5px;">Table of Contents</h2>
#     <p><a href="#section1" style="color: #2f1381; font-weight: bold; text-decoration: none;">1. Definitions of responsible AI</a></p>
#     <p><a href="#section2" style="color: #2f1381; font-weight: bold; text-decoration: none;">2. Dimensions of responsible AI</a></p>
#     <p><a href="#section3" style="color: #2f1381; font-weight: bold; text-decoration: none;">3. Where does bias come from?</a></p>
#     <ul style="margin-top: 0; padding-left: 30px;">
#         <li><a href="#section3-1" style="color: #2f1381; text-decoration: none;">3.1 Scenario: Bias in computer vision</a></li>
#         <li><a href="#section3-2" style="color: #2f1381; text-decoration: none;">3.2 Scenario: Who should become CEO?</a></li>
#         <li><a href="#section3-3" style="color: #2f1381; text-decoration: none;">3.3 Scenario: Bookworms</a></li>
#     </ul>
# </div>

# %%
# Import the knowledge check questions
from MLUMLA_EN_M3_Lab1_quiz_questions import *

# %% [markdown]
# <!-- Section Header -->
# <div id="section1" style="border-left: 5px solid #2f1381; padding-left: 15px; margin: 40px 0 20px 0;">
#     <h2 style="color: #2f1381;">1. Definitions of responsible AI</h2>
# </div>
#
# In this section, you will review several ways to define responsible AI.

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Knowledge Check</h4>
#         <p>It's time to check your knowledge of how to define responsible AI. To load the questions, run the following cells.</p>
#     </div>
# </div>

# %%
# Run this cell for a knowledge check question
question_1

# %%
# Run this cell for a knowledge check question
question_2

# %% [markdown]
# <!-- Section Header -->
# <div id="section2" style="border-left: 5px solid #2f1381; padding-left: 15px; margin: 40px 0 20px 0;">
#     <h2 style="color: #2f1381;">2. Dimensions of responsible AI</h2>
# </div>
#
# Responsible AI can describe an organizational structure, principles, and practice that support the design, build, and operation of AI systems that maximize benefits while minimizing risks and unintended impact.
#
# In this section, you will review some of these principles.

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Dimensions of Responsible AI</h4>
#         <p>It's time to check your knowledge of the dimensions of responsible AI. To load the questions, run the following cells.</p>
#     </div>
# </div>

# %%
# Run this cell for a knowledge check question
question_3

# %%
# Run this cell for a knowledge check question
question_4

# %%
# Run this cell for a knowledge check question
question_5

# %%
# Run this cell for a knowledge check question
question_6

# %%
# Run this cell for a knowledge check question
question_7

# %%
# Run this cell for a knowledge check question
question_8

# %% [markdown]
# <!-- Section Header -->
# <div id="section3" style="border-left: 5px solid #2f1381; padding-left: 15px; margin: 40px 0 20px 0;">
#     <h2 style="color: #2f1381;">3. Where does bias come from?</h2>
# </div>
#
# In this section, you will review hypothetical scenarios that can put researchers and organizations at risk of introducing bias to ML models and AI systems.

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Sources of Bias</h4>
#         <p>It's time to check your knowledge of where bias comes from.</p>
#         <p>For each of the following scenarios, read the scenario and then run the cell after the scenario to load the question.</p>
#     </div>
# </div>

# %% [markdown]
# <!-- Sub-subsection Header -->
# <div id="section3-1" style="border-left: 2px solid #7b61ff; padding-left: 10px; margin: 20px 0 15px 30px;">
#     <h4 style="color: #7b61ff;">3.1 Scenario: Bias in computer vision</h4>
# </div>
#
# A scientist is collecting image data to build a smile-detection application. To be frugal, they start by taking their own picture in different light with different resolutions and from different angles. After days of taking pictures, they only have 1,000 pictures. Because they know that computer vision models require a lot of data, they ask their family and friends for pictures to grow the dataset.
#
# __In this scenario, what bias could the resulting application exhibit?__

# %%
# Run this cell for a knowledge check question
question_9

# %% [markdown]
# <!-- Sub-subsection Header -->
# <div id="section3-2" style="border-left: 2px solid #7b61ff; padding-left: 10px; margin: 20px 0 15px 30px;">
#     <h4 style="color: #7b61ff;">3.2 Scenario: Who should become CEO?</h4>
# </div>
#
# A tech company is trying to rank potential CEO candidates. To build their ranking model, they look at the list of Fortune 500 CEOs and extract attributes of those CEOs. They even extract features from shareholder letters that the CEOs wrote to find out what makes a leader successful.
#
# __In this scenario, what hiring bias the company be showing?__

# %%
# Run this cell for a knowledge check question
question_10

# %% [markdown]
# <!-- Sub-subsection Header -->
# <div id="section3-3" style="border-left: 2px solid #7b61ff; padding-left: 10px; margin: 20px 0 15px 30px;">
#     <h4 style="color: #7b61ff;">3.3 Scenario: Bookworms</h4>
# </div>
#
# A student built an app to improve reading speed. They interviewed students on their campus and set up a website for people from all over the world to share information about their reading behavior and characteristics. Finally, the student has collected enough information and is ready to explore the data. They notice that 1 percent of the records are from people who said that they read about 300 books per year. The student, who is an avid reader, decides to discard these data points, thinking they are typos or mistakes because the student reads only as many as 50 books per year.
#
# __In this scenario, what kind of bias does the student show?__

# %%
# Run this cell for a knowledge check question
question_11

# %% [markdown]
# <div style="background-color: #f2f0fc; padding: 15px; border-radius: 5px; margin: 30px 0;">
#     <h3 style="color: #2f1381; border-bottom: 1px solid #2f1381; padding-bottom: 5px;">Conclusion</h3>
#     <p style="color: #2f1381;">In this lab, you have:</p>
#     <ul>
#         <li style="color: #2f1381;">Learned about definitions of responsible AI</li>
#         <li style="color: #2f1381;">Explored dimensions of responsible AI</li>
#         <li style="color: #2f1381;">Identified where bias comes from in ML systems</li>
#     </ul>
#     <p style="color: #2f1381;">Responsible AI is an emerging domain, and the term can be defined in different ways. To work with responsible AI in practice, you need guiding principles that you can implement as part of the ML project design and life cycle.</p>
#     <p style="color: #2f1381;">Bias has many sources. You should always assume that some type of bias impacts your project.</p>
#     <h4 style="color: #2f1381; margin-top: 15px;">Next lab</h4>
#     <p style="color: #2f1381;">In the next lab, you will practice how to measure bias in data and apply various measures of bias quantification (accuracy difference, difference in proportion of labels).</p>
# </div>

# %% [markdown]
# <p style="padding: 10px; border: 1px solid black;">
# <img src="../common/images/mlu-logo.png" alt="drawing" width="400"/> <br/>
#
# # Thank you!
