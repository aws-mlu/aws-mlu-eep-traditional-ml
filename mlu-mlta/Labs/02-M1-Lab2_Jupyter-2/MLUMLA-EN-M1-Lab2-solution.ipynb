# %% [markdown]
# <p style="padding: 10px; border: 1px solid black;">
# <img src="../common/images/mlu-logo.png" alt="drawing" width="400"/> <br/>
# <div style="background-image: linear-gradient(145deg, rgba(35, 47, 62, 1) 0%, rgba(51, 0, 102, 1) 40%, rgba(223, 42, 93, 1) 60%, rgba(124, 90, 237, 1) 85%, rgba(124, 232, 244, 1) 100%); padding: 20px; border-radius: 10px; text-align: center; margin-bottom: 30px;">
#     <h1 style="color: white; margin: 0;">MLU: ML through Application</h1>
#     <h2 style="color: white; margin-top: 15px;">Extending your Jupyter Notebook understanding</h2>
# </div>

# %% [markdown]
# <!-- Compact Lab Introduction with Activity/Challenge Explanation -->
# <div style="background-color: #F8F9F9; padding: 15px; border-radius: 5px; margin: 20px 0;">
#     <h4 style="color: #2E4053; margin-top: 0;">About This Lab</h4>
#     <p>Throughout this lab, you will encounter two types of interactive elements:</p>
#     <table style="width: 100%; border-collapse: collapse; margin: 15px 0;">
#         <tr>
#             <td style="text-align: center; padding: 10px; width: 50%;">
#                 <img src="../common/images/mlu-activity.png" alt="Activity" width="125"/>
#             </td>
#             <td style="text-align: center; padding: 10px; width: 50%;">
#                 <img src="../common/images/mlu-challenge.png" alt="Challenge" width="125"/>
#             </td>
#         </tr>
#         <tr>
#             <td style="text-align: center; padding: 10px; background-color: #EBF5FB;">
#                 <p>No coding is needed for an activity. You try to understand a concept, <br/>answer questions, or run a code cell.</p>
#             </td>
#             <td style="text-align: center; padding: 10px; background-color: #FEF9E7;">
#                 <p>Challenges are where you test your understanding by implementing something new or taking a short quiz.</p>
#             </td>
#         </tr>
#     </table>
#     <p>Please work through this notebook from top to bottom to avoid errors due to missing code or context.</p>
# </div>

# %% [markdown]
# <!-- Table of Contents with All Section Levels -->
# <div style="background-color: #f2f0fc; padding: 15px; border-radius: 5px; margin-bottom: 30px;">
#     <h2 style="color: #2f1381; border-bottom: 1px solid #2f1381; padding-bottom: 5px;">Table of Contents</h2>
#     <p><a href="#section1" style="color: #2f1381; font-weight: bold; text-decoration: none;">1. Writing shell commands</a></p>
#     <p><a href="#section2" style="color: #2f1381; font-weight: bold; text-decoration: none;">2. Magic commands</a></p>
#     <ul style="margin-top: 0; padding-left: 30px;">
#         <li><a href="#section2-1" style="color: #2f1381; text-decoration: none;">2.1 History of code cells that have run</a></li>
#         <li><a href="#section2-2" style="color: #2f1381; text-decoration: none;">2.2 Printing in HTML style</a></li>
#         <li><a href="#section2-3" style="color: #2f1381; text-decoration: none;">2.3 Running other languages</a></li>
#     </ul>
#     <p><a href="#section3" style="color: #2f1381; font-weight: bold; text-decoration: none;">3. Keyboard shortcuts</a></p>
# </div>

# %% [markdown]
# Jupyter notebooks are a key development tool for ML projects. The previous lab introduced you to the Jupyter Notebook application. By the end of this notebook, you should be able to use some special Jupyter features.
#
# You will learn how to do the following:
# - Explain what magic commands are.
# - Load data into the Jupyter Notebook application.
# - Use shortcuts to navigate the Jupyter Notebook application.
#
# __Note:__ These lab instructions are written for using Jupyter, not JupyterLab. You might encounter differences in the UI if you run this lab in JupyterLab.

# %% [markdown]
# First, you need to import the libraries that are needed for this notebook. You will learn more about importing libraries later.

# %%
import time

from MLUMLA_EN_M1_Lab2_quiz_questions import *

# %% [markdown]
# <!-- Section Header -->
# <div id="section1" style="border-left: 5px solid #2f1381; padding-left: 15px; margin: 40px 0 20px 0;">
#     <h2 style="color: #2f1381;">1. Writing shell commands</h2>
# </div>
#
# The Jupyter Notebook application runs on a Linux instance. To write bash commands in a notebook, preface them with `!`. In other words, you can use `![command]` to run shell commands, such as in the following example:

# %%
# Print the current date in UTC
# !date

# %% [markdown]
# You can use `!` with `pip` to install libraries into the kernel, such as the `matplotlib` library in the following example:

# %%
# Install matplotlib on the kernel
# !pip install matplotlib

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Try it yourself!</h4>
#         <p>In the following cell, run the <code>ls</code> command.</p>
#     </div>
# </div>

# %%
# Run the ls shell command here
############### CODE HERE ###############

# !ls

############## END OF CODE ##############

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Knowledge Check</h4>
#         <p>To load the question, run the following cell.</p>
#     </div>
# </div>

# %%
# Run this cell for a knowledge check question
question_1

# %% [markdown]
# <!-- Section Header -->
# <div id="section2" style="border-left: 5px solid #2f1381; padding-left: 15px; margin: 40px 0 20px 0;">
#     <h2 style="color: #2f1381;">2. Magic commands</h2>
# </div>
#
# In code cells in a Jupyter notebook, you can use magic commands to run special functions that only work in a notebook. For example, you can use a magic command to look at the command history of your notebook or run a different programming language (such as HTML or JavaScript) than your current kernel.
#
# Preface magic commands with `%` (and use `%%` for a different programming language).
#
# __Note:__ Doubled magic commands (that begin with `%%`) should be the first line of code in a cell.

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Try it yourself!</h4>
#         <p>In the next few code cells, you will practice using some magic commands.</p>
#     </div>
# </div>

# %% [markdown]
# <!-- Subsection Header -->
# <div id="section2-1" style="border-left: 3px solid #4C32E2; padding-left: 12px; margin: 25px 0 15px 15px;">
#     <h3 style="color: #4C32E2;">2.1 History of code cells that have run</h3>
# </div>
#
# The magic command in the following code cell shows the history of all cells that have run since the last kernel restart.
#
# Restart the kernel now and run a few code cells. Then, use the following magic command to see the history. The code cells are listed in the order that they were run.

# %%
# Look at the history of code cells that have run
# %history

# %% [markdown]
# <!-- Subsection Header -->
# <div id="section2-2" style="border-left: 3px solid #4C32E2; padding-left: 12px; margin: 25px 0 15px 15px;">
#     <h3 style="color: #4C32E2;">2.2 Printing in HTML style</h3>
# </div>
#
# The magic command in the following code cell shows how to use HTML to format text in a notebook.

# %%
# %%html
#
# <h2 style="color: red; border: 2px solid black; text-align: center;">This is HTML.</h2>

# %% [markdown]
# <!-- Subsection Header -->
# <div id="section2-3" style="border-left: 3px solid #4C32E2; padding-left: 12px; margin: 25px 0 15px 15px;">
#     <h3 style="color: #4C32E2;">2.3 Running other languages</h3>
# </div>
#
# The magic command in the following code cell shows how to run JavaScript code. In this example, the JavaScript code opens a pop-up window.

# %%
# %%javascript
#
# alert('Sorry for this pop-up!')

# %% [markdown]
# <!-- Challenge Box -->
# <div style="background-color: #FEF9E7; border-left: 5px solid #F1C40F; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-challenge.png" alt="Challenge" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #B7950B; margin-top: 0;">Challenge: Try it yourself!</h4>
#         <p>For more information about magic commands, see <a href="https://ipython.readthedocs.io/en/stable/interactive/magics.html">Built-in Magic Commands</a> in the IPython documentation.</p>
#         <p>Research how to use a magic command to time how long a Python statement or expression takes to run in a notebook.</p>
#         <p>Then, use the command to time how long it takes to run the expression in the following code cell.</p>
#         <p><strong>Hint:</strong> Search for the <code>timeit</code> magic command.</p>
#         <p><strong>Note:</strong> Doubled magic commands (that begin with <code>%%</code>) should be the first line of code in a cell.</p>
#     </div>
# </div>

# %%
# %%timeit

# Write before this line

# Time how long it takes to run the following expression

throwaway = [i*2 for i in range(1000000)]

# %% [markdown]
# <!-- Section Header -->
# <div id="section3" style="border-left: 5px solid #2f1381; padding-left: 15px; margin: 40px 0 20px 0;">
#     <h2 style="color: #2f1381;">3. Keyboard shortcuts</h2>
# </div>
#
# Jupyter notebooks have two different sets of keyboard shortcuts: one set that is active in edit mode and another that is active in in command mode. If you see a pencil next to the kernel type in the top-right corner, you're in edit mode. Otherwise, you're in command mode.
#
# The most important keyboard shortcuts are Enter, which enters edit mode, and Esc, which enters command mode.
#
# In edit mode, most of the keyboard is dedicated to typing into the cell's editor. Therefore, only a few shortcuts are available in edit mode.
#
# In command mode, the entire keyboard is available for shortcuts, so more shortcuts are available. To see the available shortcuts, choose **Help** > **Keyboard Shortcuts** dialog lists the available shortcuts.
#
# The following shortcuts for command mode are especially helpful to learn:
#
# - Basic navigation:
#     - Enter: Enter edit mode
#     - Shift+Enter: Run the selected cell
#     - Up arrow key or k: Move to the previous cell
#     - Down arrow key or j: Move to the next cell
# - Save the notebook: s
# - Change cell types:
#      - y: Code
#      - m: Markdown
#      - 1 through 6: Indicate the header level for a Markdown cell (for example, 1 is an h1 or `#` heading)
# - Create a cell:
#     - a: Create a cell before the currently selected cell
#     - b: Create a cell after the currently selected cell
# - Edit a cell:
#     - x: Cut
#     - c: Copy
#     - v: Paste
#     - dd: Delete
#     - z: Undo
# - Operate the kernel:
#     - i,i: Interrupt the kernel
#     - 0,0: Restart the kernel

# %% [markdown]
# <!-- Activity Box -->
# <div style="background-color: #EBF5FB; border-left: 5px solid #3498DB; padding: 15px; border-radius: 5px; margin: 20px 0; display: flex; align-items: flex-start;">
#     <div style="flex: 0 0 60px; margin-right: 15px;">
#         <img src="../common/images/mlu-activity.png" alt="Activity" width="200" style="max-width: 100%; height: auto;">
#     </div>
#     <div style="flex: 1;">
#         <h4 style="color: #2874A6; margin-top: 0;">Activity: Knowledge Check</h4>
#         <p>To load the question, run the following cell.</p>
#     </div>
# </div>

# %%
# Run this cell for a knowledge check question
question_2

# %% [markdown]
# <div style="background-color: #f2f0fc; padding: 15px; border-radius: 5px; margin: 30px 0;">
#     <h3 style="color: #2f1381; border-bottom: 1px solid #2f1381; padding-bottom: 5px;">Conclusion</h3>
#     <p style="color: #2f1381;">In this lab, you have:</p>
#     <ul>
#         <li style="color: #2f1381;">Learned how to use shell commands in Jupyter notebooks</li>
#         <li style="color: #2f1381;">Explored magic commands for special notebook functions</li>
#         <li style="color: #2f1381;">Discovered keyboard shortcuts for efficient notebook navigation</li>
#     </ul>
#     <h4 style="color: #2f1381; margin-top: 15px;">Next lab</h4>
#     <p style="color: #2f1381;">In the next lab, you will learn how to explore a dataset that contains information about books. The goal will be to predict book prices by using book features.</p>
# </div>

# %% [markdown]
# <p style="padding: 10px; border: 1px solid black;">
# <img src="../common/images/mlu-logo.png" alt="drawing" width="400"/> <br/>
#
# # Thank you!
